# %% [markdown]
# # Python爬取中国天气网天气

# %%
#coding:utf8
import requests
import bs4
import pprint
import re
from twilio.rest import Client
import smtplib
from email.mime.text import MIMEText
from email.utils import formataddr

#url = "http://www.weather.com.cn/weather/101300101.shtml" #南宁天气网址

class getWeather():
    '''
    爬取中国天气网某地七天内天气
    '''
    def __init__(self,url):
        self.response = requests.get(url)
        self.response.encoding='utf-8'
        self.soup = bs4.BeautifulSoup(self.response.text,'html.parser')
        self.res = self.get_weather_seven()
        self.life = self.get_life_num()
        self.body = "\n".join(self.res) + "     " + "\n" + "\n".join(self.life)+ "\n"+"\n".join(self.get_concre_data())
        pprint.pprint(self.body)

    def get_concre_data(self):
        concre_data_time = self.soup.select("script")
        #print(concre_data_time[2].string[15:-1])
        d = json.loads(concre_data_time[2].string[15:-1])
        #pprint.pprint(d["7d"][:3])
        res = ["未来三天内详细天气信息",]
        for i in d["7d"][:3]:
            for j in i:
                res.append(re.sub(r',','    ',j[:6]+j[10:-2]))
        return res
    
    def get_weather_seven(self):#获取七天内天气
        list1 = self.soup.select('ul[class="t clearfix"] > li')
        res_weather = ["未来七天内天气信息",]
        for i in list1:
            weather = ""
            tem_i = i.select("p[class='tem'] > i")[0].string
            if i.select("p[class='tem'] > span") != []:
                tem_span = i.select("p[class='tem'] > span")[0].string
            else:
                tem_span = i.select("p[class='tem'] > span")
            win = i.select("p[class='win'] > em > span")
            weather = i.select("h1")[0].string+"    "
            weather += i.select("p[class='wea']")[0].string + "    "
            if win != []:
                if len(win) == 1:
                    weather += win[0]["title"]
                elif len(win) == 2:
                    weather += win[0]["title"] + "转"+win[1]["title"]
            weather += "  "+i.select("p[class='win'] > i")[0].string+"    "
            if tem_span != []:
                weather += (tem_span+" ~ "+tem_i)
            elif tem_i != []:
                weather += tem_i
            res_weather.append(weather)
        return res_weather
    
    def get_life_num(self):   #获取当天天气的健康提示信息
        life_num = self.soup.select("ul[class='clearfix'] > li")
        res_life = ["今天健康提示",]
        res_life.append(life_num[0].select("em")[0].string+":"+life_num[0].select("span")[0].string+" "+life_num[0].select("p")[0].string)
        res_life.append(life_num[1].select("p")[0].string)
        res_life.append(life_num[2].select("em")[0].string+":"+life_num[2].select("span")[0].string+" "+life_num[2].select("p")[0].string)
        res_life.append(life_num[3].select("span")[0].string+" "+life_num[3].select("p")[0].string)
        res_life.append(life_num[4].select("em")[0].string+":"+life_num[4].select("span")[0].string+" "+life_num[4].select("p")[0].string)
        res_life.append(life_num[5].select("em")[0].string+":"+life_num[5].select("span")[0].string+" "+life_num[5].select("p")[0].string)
        return res_life
    
    
class send_email_of_weather():
    '''
    发送邮件
    '''
    def __init__(self,receiver,subject,body):
        self.sender = '3295468820@qq.com'    # 发件人邮箱账号
        self.psd = 'nlropspeooyvdaii'       # 发件人邮箱密码(当时申请smtp给的口令)
        if receiver is not None:
            for i in receiver:
                if i == '1602983878@qq.com':
                    subject = "给最最最可爱的姝姝"
                ret = self.mail(i,subject,body)
                if ret:
                    print("邮件发送%s成功"%i)
                else:
                    print("邮件发送%s失败"%i)
    #my_sender='3295468820@qq.com'    # 发件人邮箱账号
    #my_pass = 'nlropspeooyvdaii'              # 发件人邮箱密码(当时申请smtp给的口令)
    #receiver='1602983878@qq.com'      # 收件人邮箱账号
    def mail(self,receiver,subject,body):
        ret=True
        try:
            msg=MIMEText(body,'plain','utf-8')
            msg['From']= formataddr(["发件人昵称",self.sender])  # 括号里的对应发件人邮箱昵称、发件人邮箱账号
            msg['To']= formataddr(["收件人昵称",receiver])              # 括号里的对应收件人邮箱昵称、收件人邮箱账号
            #msg['Subject']="给最最最可爱的姝姝"                # 邮件的主题，也可以说是标题
            msg['Subject']= subject
            
            server=smtplib.SMTP_SSL("smtp.qq.com", 465)  # 发件人邮箱中的SMTP服务器，端口是465
            server.login(self.sender, self.psd)  # 括号中对应的是发件人邮箱账号、邮箱密码
            
            server.sendmail(self.sender,[receiver,],msg.as_string())  # 括号中对应的是发件人邮箱账号、收件人邮箱账号、发送邮件
            #print("login ok")
            server.quit()# 关闭连接
        except Exception:# 如果 try 中的语句没有执行，则会执行下面的 ret=False
            print("Failed to send email to "+receiver)
            ret=False
        return ret

if __name__ == '__main__':
    #url顺序是姝姝南宁天气和博白天气，南宁天气，哈尔滨天气
    url = ["http://www.weather.com.cn/weather/101300902.shtml","http://www.weather.com.cn/weather/101300101.shtml","http://www.weather.com.cn/weather/101050101.shtml"]
    receiver = [["2311077029@qq.com","1423237806@qq.com","2019607084@qq.com"],["1194157042@qq.com",'1602983878@qq.com'],["3295468820@qq.com"]]#'1602983878@qq.com'
    subject = ["博白天气","南宁天气","哈尔滨天气"]
    #my_dict = {"给最最最可爱的姝姝":['1602983878@qq.com'] ,"博白天气":["2311077029@qq.com","2311077029@qq.com"],"南宁天气":["1194157042@qq.com"]}
    j = 0
    for i in url:
        weather = getWeather(i)
        body = weather.body
        send_email = send_email_of_weather(receiver[j],subject[j],body)
        j += 1
        #print(receiver[i]+subject[i])
#send_message_to_phone(res)    
#pprint.pprint(body)
# Out:
# ('未来七天内天气信息\n'
#  '20日（今天）    中雨转阵雨    东南风转东南风  <3级    33 ~ 25℃\n'
#  '21日（明天）    中雨    东北风转东北风  <3级    32 ~ 25℃\n'
#  '22日（后天）    阵雨转多云    东北风转西南风  <3级    33 ~ 26℃\n'
#  '23日（周一）    大雨转中雨    北风转西北风  <3级    31 ~ 24℃\n'
#  '24日（周二）    中雨    东南风转东南风  <3级    31 ~ 26℃\n'
#  '25日（周三）    小雨转多云    北风转北风  <3级    31 ~ 25℃\n'
#  '26日（周四）    阵雨转多云    东南风转东风  <3级    33 ~ 25℃     \n'
#  '今天健康提示\n'
#  '紫外线指数:弱 辐射较弱，涂擦SPF12-15、PA+护肤品。\n'
#  '天气闷热，坚持室内低强度运动。\n'
#  '健臻·血糖指数:较易波动 血糖较易波动，注意监测。\n'
#  '炎热 建议穿短衫、短裤等清凉夏季服装。\n'
#  '洗车指数:不宜 有雨，雨水和泥水会弄脏爱车。\n'
#  '空气污染扩散指数:优 气象条件非常有利于空气污染物扩散。\n'
#  '未来三天内详细天气信息\n'
#  '20日08时    小雨    27℃    东南风    <3级\n'
#  '20日11时    中雨    31℃    东南风    <3级\n'
#  '20日14时    小雨    32℃    东南风    <3级\n'
#  '20日17时    小雨    32℃    东南风    <3级\n'
#  '20日20时    小雨    28℃    东南风    <3级\n'
#  '20日23时    阵雨    27℃    东南风    <3级\n'
#  '21日02时    阵雨    26℃    东南风    <3级\n'
#  '21日05时    多云    25℃    东南风    <3级\n'
#  '21日08时    多云    27℃    东南风    <3级\n'
#  '21日11时    中雨    28℃    东北风    <3级\n'
#  '21日14时    中雨    31℃    东北风    <3级\n'
#  '21日17时    小雨    29℃    东北风    <3级\n'
#  '21日20时    小雨    28℃    东北风    <3级\n'
#  '21日23时    中雨    26℃    东北风    <3级\n'
#  '22日02时    中雨    26℃    东北风    <3级\n'
#  '22日05时    中雨    25℃    东北风    <3级\n'
#  '22日08时    中雨    26℃    东北风    <3级\n'
#  '22日11时    多云    30℃    东北风    <3级\n'
#  '22日14时    阵雨    32℃    东北风    <3级\n'
#  '22日17时    阵雨    31℃    东北风    <3级\n'
#  '22日20时    阵雨    28℃    东北风    <3级\n'
#  '22日23时    多云    28℃    西南风    <3级\n'
#  '23日02时    多云    27℃    西南风    <3级\n'
#  '23日05时    多云    26℃    西南风    <3级')
# True
# 邮件发送1602983878@qq.com成功
# ('未来七天内天气信息\n'
#  '20日（今天）    雷阵雨    东南风转东风  <3级    33 ~ 25℃\n'
#  '21日（明天）    中雨转多云    东南风转东南风  <3级    33 ~ 25℃\n'
#  '22日（后天）    中雨转多云    南风转东南风  <3级    33 ~ 26℃\n'
#  '23日（周一）    中雨转小雨    东风转东北风  <3级    34 ~ 26℃\n'
#  '24日（周二）    小雨    南风转北风  <3级    34 ~ 26℃\n'
#  '25日（周三）    小雨    东南风转东风  3-4级转<3级    34 ~ 25℃\n'
#  '26日（周四）    中雨    南风转东北风  3-4级转<3级    34 ~ 25℃     \n'
#  '今天健康提示\n'
#  '紫外线指数:中等 涂擦SPF大于15、PA+防晒护肤品。\n'
#  '天气闷热，坚持室内低强度运动。\n'
#  '健臻·血糖指数:较易波动 血糖较易波动，注意监测。\n'
#  '炎热 建议穿短衫、短裤等清凉夏季服装。\n'
#  '洗车指数:不宜 有雨，雨水和泥水会弄脏爱车。\n'
#  '空气污染扩散指数:良 气象条件有利于空气污染物扩散。\n'
#  '未来三天内详细天气信息\n'
#  '20日08时    小雨    27℃    东南风    <3级\n'
#  '20日11时    雷阵雨    32℃    东南风    <3级\n'
#  '20日14时    雷阵雨    32℃    东南风    <3级\n'
#  '20日17时    雷阵雨    30℃    东南风    <3级\n'
#  '20日20时    雷阵雨    28℃    东南风    <3级\n'
#  '20日23时    多云    27℃    东风    <3级\n'
#  '21日02时    多云    26℃    东风    <3级\n'
#  '21日05时    雷阵雨    25℃    东风    <3级\n'
#  '21日08时    多云    26℃    东风    <3级\n'
#  '21日11时    中雨    29℃    东南风    <3级\n'
#  '21日14时    中雨    32℃    东南风    <3级\n'
#  '21日17时    中雨    30℃    东南风    <3级\n'
#  '21日20时    小雨    28℃    东南风    <3级\n'
#  '21日23时    多云    27℃    东南风    <3级\n'
#  '22日02时    多云    25℃    东南风    <3级\n'
#  '22日05时    多云    25℃    东南风    <3级\n'
#  '22日08时    多云    26℃    东南风    <3级\n'
#  '22日11时    中雨    31℃    南风    <3级\n'
#  '22日14时    小雨    32℃    南风    <3级\n'
#  '22日17时    中雨    30℃    南风    <3级\n'
#  '22日20时    多云    28℃    南风    <3级\n'
#  '22日23时    多云    27℃    东南风    <3级\n'
#  '23日02时    多云    27℃    东南风    <3级\n'
#  '23日05时    多云    26℃    东南风    <3级')
# 邮件发送2311077029@qq.com成功
# 邮件发送1423237806@qq.com成功
# 邮件发送2019607084@qq.com成功
# ('未来七天内天气信息\n'
#  '20日（今天）    中雨转阵雨    东南风转东南风  <3级    33 ~ 25℃\n'
#  '21日（明天）    中雨    东北风转东北风  <3级    32 ~ 25℃\n'
#  '22日（后天）    阵雨转多云    东北风转西南风  <3级    33 ~ 26℃\n'
#  '23日（周一）    大雨转中雨    北风转西北风  <3级    31 ~ 24℃\n'
#  '24日（周二）    中雨    东南风转东南风  <3级    31 ~ 26℃\n'
#  '25日（周三）    小雨转多云    北风转北风  <3级    31 ~ 25℃\n'
#  '26日（周四）    阵雨转多云    东南风转东风  <3级    33 ~ 25℃     \n'
#  '今天健康提示\n'
#  '紫外线指数:弱 辐射较弱，涂擦SPF12-15、PA+护肤品。\n'
#  '天气闷热，坚持室内低强度运动。\n'
#  '健臻·血糖指数:较易波动 血糖较易波动，注意监测。\n'
#  '炎热 建议穿短衫、短裤等清凉夏季服装。\n'
#  '洗车指数:不宜 有雨，雨水和泥水会弄脏爱车。\n'
#  '空气污染扩散指数:优 气象条件非常有利于空气污染物扩散。\n'
#  '未来三天内详细天气信息\n'
#  '20日08时    小雨    27℃    东南风    <3级\n'
#  '20日11时    中雨    31℃    东南风    <3级\n'
#  '20日14时    小雨    32℃    东南风    <3级\n'
#  '20日17时    小雨    32℃    东南风    <3级\n'
#  '20日20时    小雨    28℃    东南风    <3级\n'
#  '20日23时    阵雨    27℃    东南风    <3级\n'
#  '21日02时    阵雨    26℃    东南风    <3级\n'
#  '21日05时    多云    25℃    东南风    <3级\n'
#  '21日08时    多云    27℃    东南风    <3级\n'
#  '21日11时    中雨    28℃    东北风    <3级\n'
#  '21日14时    中雨    31℃    东北风    <3级\n'
#  '21日17时    小雨    29℃    东北风    <3级\n'
#  '21日20时    小雨    28℃    东北风    <3级\n'
#  '21日23时    中雨    26℃    东北风    <3级\n'
#  '22日02时    中雨    26℃    东北风    <3级\n'
#  '22日05时    中雨    25℃    东北风    <3级\n'
#  '22日08时    中雨    26℃    东北风    <3级\n'
#  '22日11时    多云    30℃    东北风    <3级\n'
#  '22日14时    阵雨    32℃    东北风    <3级\n'
#  '22日17时    阵雨    31℃    东北风    <3级\n'
#  '22日20时    阵雨    28℃    东北风    <3级\n'
#  '22日23时    多云    28℃    西南风    <3级\n'
#  '23日02时    多云    27℃    西南风    <3级\n'
#  '23日05时    多云    26℃    西南风    <3级')
# 邮件发送1194157042@qq.com成功
# ('未来七天内天气信息\n'
#  '20日（今天）    雷阵雨转小雨    西南风转西南风  3-4级    29 ~ 24℃\n'
#  '21日（明天）    多云    西南风转西南风  3-4级转<3级    30 ~ 25℃\n'
#  '22日（后天）    多云    西南风转西南风  3-4级转<3级    33 ~ 25℃\n'
#  '23日（周一）    多云    西南风转西南风  <3级    33 ~ 25℃\n'
#  '24日（周二）    雷阵雨转中雨    北风转北风  3-4级转<3级    28 ~ 22℃\n'
#  '25日（周三）    大雨转中雨    东风转北风  3-4级转<3级    22 ~ 19℃\n'
#  '26日（周四）    雷阵雨转中雨    东风转西北风  <3级    26 ~ 18℃     \n'
#  '今天健康提示\n'
#  '紫外线指数:弱 辐射较弱，涂擦SPF12-15、PA+护肤品。\n'
#  '风雨相伴，坚持室内运动吧。\n'
#  '健臻·血糖指数:易波动 血糖易波动，注意监测。\n'
#  '热 适合穿T恤、短薄外套等夏季服装。\n'
#  '洗车指数:不宜 有雨，雨水和泥水会弄脏爱车。\n'
#  '空气污染扩散指数:良 气象条件有利于空气污染物扩散。\n'
#  '未来三天内详细天气信息\n'
#  '20日08时    小雨    24℃    西南风    3-4级\n'
#  '20日11时    阴    27℃    西南风    3-4级\n'
#  '20日14时    阴    28℃    西南风    3-4级\n'
#  '20日17时    阴    27℃    西南风    <3级\n'
#  '20日20时    雷阵雨    25℃    西南风    <3级\n'
#  '20日23时    小雨    25℃    西南风    <3级\n'
#  '21日02时    小雨    25℃    西南风    3-4级\n'
#  '21日05时    小雨    24℃    西南风    3-4级\n'
#  '21日08时    小雨    25℃    西南风    3-4级\n'
#  '21日11时    多云    27℃    西南风    3-4级\n'
#  '21日14时    多云    29℃    西南风    3-4级\n'
#  '21日17时    多云    29℃    西南风    3-4级\n'
#  '21日20时    多云    27℃    西南风    <3级\n'
#  '21日23时    多云    27℃    西南风    <3级\n'
#  '22日02时    多云    27℃    西南风    <3级\n'
#  '22日05时    多云    25℃    西南风    <3级\n'
#  '22日08时    多云    27℃    西南风    <3级\n'
#  '22日11时    多云    31℃    西南风    3-4级\n'
#  '22日14时    多云    32℃    西南风    3-4级\n'
#  '22日17时    多云    32℃    西南风    <3级\n'
#  '22日20时    多云    28℃    西南风    <3级\n'
#  '22日23时    多云    28℃    西南风    <3级\n'
#  '23日02时    多云    26℃    西南风    <3级\n'
#  '23日05时    多云    25℃    西南风    <3级')
# 邮件发送3295468820@qq.com成功

# %%
#coding:utf8
import requests
import bs4
import pprint
import json
import re

url = "http://www.weather.com.cn/weather/101050101.shtml"
response = requests.get(url)
response.encoding='utf-8'
soup = bs4.BeautifulSoup(response.text,'html.parser')

def get_concre_data():
    concre_data_time = soup.select("script")
    #print(concre_data_time[2].string[15:-1])
    d = json.loads(concre_data_time[2].string[15:-1])
    pprint.pprint(d["7d"][:3])
    res = []
    for i in d["7d"][:3]:
        for j in i:
            res.append(re.sub(r',','    ',j[:6]+j[10:-2]))
    return "\n".join(res)
pprint.pprint(get_concre_data())
# Out:
# [['20日08时,d07,小雨,24℃,西南风,3-4级,3',
#   '20日11时,d02,阴,27℃,西南风,3-4级,3',
#   '20日14时,d02,阴,28℃,西南风,3-4级,3',
#   '20日17时,d02,阴,27℃,西南风,<3级,3',
#   '20日20时,n04,雷阵雨,25℃,西南风,<3级,0',
#   '20日23时,n07,小雨,25℃,西南风,<3级,0',
#   '21日02时,n07,小雨,25℃,西南风,3-4级,0',
#   '21日05时,n07,小雨,24℃,西南风,3-4级,0'],
#  ['21日08时,d07,小雨,25℃,西南风,3-4级,3',
#   '21日11时,d01,多云,27℃,西南风,3-4级,3',
#   '21日14时,d01,多云,29℃,西南风,3-4级,2',
#   '21日17时,d01,多云,29℃,西南风,3-4级,3',
#   '21日20时,n01,多云,27℃,西南风,<3级,0',
#   '21日23时,n01,多云,27℃,西南风,<3级,0',
#   '22日02时,n01,多云,27℃,西南风,<3级,0',
#   '22日05时,n01,多云,25℃,西南风,<3级,0'],
#  ['22日08时,d01,多云,27℃,西南风,<3级,2',
#   '22日11时,d01,多云,31℃,西南风,3-4级,2',
#   '22日14时,d01,多云,32℃,西南风,3-4级,2',
#   '22日17时,d01,多云,32℃,西南风,<3级,2',
#   '22日20时,n01,多云,28℃,西南风,<3级,0',
#   '22日23时,n01,多云,28℃,西南风,<3级,0',
#   '23日02时,n01,多云,26℃,西南风,<3级,0',
#   '23日05时,n01,多云,25℃,西南风,<3级,0']]
# ('20日08时    小雨    24℃    西南风    3-4级\n'
#  '20日11时    阴    27℃    西南风    3-4级\n'
#  '20日14时    阴    28℃    西南风    3-4级\n'
#  '20日17时    阴    27℃    西南风    <3级\n'
#  '20日20时    雷阵雨    25℃    西南风    <3级\n'
#  '20日23时    小雨    25℃    西南风    <3级\n'
#  '21日02时    小雨    25℃    西南风    3-4级\n'
#  '21日05时    小雨    24℃    西南风    3-4级\n'
#  '21日08时    小雨    25℃    西南风    3-4级\n'
#  '21日11时    多云    27℃    西南风    3-4级\n'
#  '21日14时    多云    29℃    西南风    3-4级\n'
#  '21日17时    多云    29℃    西南风    3-4级\n'
#  '21日20时    多云    27℃    西南风    <3级\n'
#  '21日23时    多云    27℃    西南风    <3级\n'
#  '22日02时    多云    27℃    西南风    <3级\n'
#  '22日05时    多云    25℃    西南风    <3级\n'
#  '22日08时    多云    27℃    西南风    <3级\n'
#  '22日11时    多云    31℃    西南风    3-4级\n'
#  '22日14时    多云    32℃    西南风    3-4级\n'
#  '22日17时    多云    32℃    西南风    <3级\n'
#  '22日20时    多云    28℃    西南风    <3级\n'
#  '22日23时    多云    28℃    西南风    <3级\n'
#  '23日02时    多云    26℃    西南风    <3级\n'
#  '23日05时    多云    25℃    西南风    <3级')

# %%
mystr = "fhksj hjhkhfkashbkfhsfhjk"+"\n"+"fhskjdfhdsjka"
print(mystr)
# Out:
# fhksj hjhkhfkashbkfhsfhjk
# fhskjdfhdsjka
